# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Position_Salaries.csv')
x = data.iloc[:, 1:-1].values
y = data.iloc[:, -1].values

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(random_state = 0)
reg.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
reg.predict([[6.5]])
# Out:
# [ 45000  50000  60000  80000 110000 150000 200000 300000 500000 800000]

# %%
plt.scatter(x, y, color = 'red')
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape(len(x_grid), 1)
plt.plot(x_grid, reg.predict(x_grid), color = 'blue')

# %%
#Graph is smooth because here we only predict given point not grid. And for plotting it just connects different predicted values
#So predicted value of 6.5 is different as compared to graph below.
plt.scatter(x, y, color = 'red')
plt.plot(x, reg.predict(x), color = 'blue')
